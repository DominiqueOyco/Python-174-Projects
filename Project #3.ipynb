# %% [markdown]
# # CECS 174 Project #3: Tweet Decoder
# ## Programming Task
#
# Create a program that allows the user to enter a complete tweet (160 characters or less) as a single line of text. Your program must
#
# 1. search the resulting string for abbreviations and print a list of each abbreviation along with its decoded meaning.
# 2. convert the user's tweet to a decoded tweet, replacing the abbreviations directly within the tweet.  It may help you to search how to use the function `replace()`.  This site contains a good example https://www.tutorialspoint.com/python/string_replace.htm.  Have fun!
#
# The abbreviations it must search for are:
#
# *    AFAIK = As far as I know
# *    B4 = Before
# *    BFN = Bye for now
# *    BR = Best regards
# *    BTW = By the way
# *    CUL8R = See you later
# *    DAM = Don’t annoy me
# *    EMA = Email address
# *    F2F /FTF = Face to face
# *    FB = Facebook
# *    HAGN = Have a good night
# *    HAND = Have a nice day
# *    HOTD = Headline of the day
# *    HTH = Hope that helps
# *    IC = I see
# *    ICYMI = "In case you missed it," a quick way to apologize for retweeting your own material
# *    IDK = I don't know
# *    IIRC = If I remember correctly
# *    IMHO = In my humble opinion.
# *    JK = Just kidding, joke
# *    JSYK = Just so you know
# *    KK = Kewl kewl, or ok, got it
# *    LHH = Laugh hella hard (stronger version of LOL)
# *    LMK = Let me know
# *    LOL = Laugh out loud
# *    NBD = No big deal
# *    NCT = Nobody cares, though
# *    NJoy = Enjoy
# *    PLMK = Please let me know
# *    SMH = Shaking my head
# *    SRS = Serious
# *    TY = Thank you
# *    TYIA = Thank you in advance
# *    TYVW = Thank you very much
# *    U = You
# *    UR = your
# *    WTV = Whatever
# *    YGTR = You got that right
# *    YOLO = You only live once
# *    YOYO = You're on your own
# *    YW = You're welcome
# *    ZOMG = OMG to the max

# %%
tweet_abbrev = {'LOL' : "laughing out loud", 'BFN' : "bye for now", 'IRL' : "in real life", 'ROFL' : ""}

text = input("Enter a tweet up to 160 characters or less: ")
# Out:
# Enter a tweet up to 160 characters or less: k

# %% [markdown]
# ## Data Structures Needed (i.e. Containers)
#
# * dictionary
#     * key = abbreviation
#     * value = definition of valid abbrevations

# %% [markdown]
# ## Task Decomposition:
#
# 1. Ask the user for tweet abbreviations they want to know
# 2. Store in appropriate containers
# 3. Determine if the input is a valid abbreviation
# 4. If the abbreviation is valid, print the definition of the word
# 5. If the abbreviation is invalid, show the user the abbrevation is not valid

# %% [markdown]
# ### Algorithm
#
# * Define empty containers
# * Accept input
# * Determine if the input is a valid abbreviation
# * Print the definition of the input if valid. Otherwise show the input is invalid

# %% [markdown]
# ## Code:

# %%
tweet_abbrev = {'AFAIK' : "As far as I know", 
                'B4' : "Before",
                'BFN' : "Bye for now",
                'BR' : "Best regards",
                'BTW' : "By the way",
                'CUL8R' : "See you later",
                'DAM' : "Don’t annoy me",
                'EMA' : "Email address",
                'F2F' : "Face to face",
                'FTF' : "Face to face",
                'FB' : "Facebook",
                'HAGN' : "Have a good night",
                'HAND' : "Have a nice day",
                'HOTD' : "Headline of the day",
                'HTH' : "Hope that helps",
                'IC' : "I see",
                'ICYMI' : "In case you missed it",
                'IDK' : "I don't know",
                'IIRC' : "If I remember correctly",
                'IMHO' : "In my humble opinion",
                'JK' : "Just kidding, joke",
                'JSYK' : "Just so you know",
                'KK' : "Kewl kewl, or ok, got it",
                'LHH' : "Laugh hella hard",
                'LMK' : "Let me know",
                'LOL' : "Laugh out loud",
                'NBD' : "No big deal",
                'NCT' : "Nobody cares, though",
                'NJoy' : "Enjoy",
                'PLMK' : "Please let me know",
                'SMH' : "Shaking my head", 
                'SRS' : "Serious",
                'TY' : "Thank you",
                'TYIA' : "Thank you in advance",
                'TYVW' : "Thank you very much",
                'U' : "You",
                'UR' : "Your", 
                'WTV' : "Whatever",
                'YGTR' : "You got that right",
                'YOLO' : "You only live once",
                'YOYO' : "You're on your own",
                'YW' : "You're welcome",
                'ZOMG' : "OMG to the max"}
                
userText = input("Please enter a tweet that is 160 characters or less: ").upper()  

if 'AFAIK' in userText:
    print("AFAIK = %s" % tweet_abbrev['AFAIK'])
    print(userText.replace('AFAIK', tweet_abbrev['AFAIK']).lower())

elif 'B4' in userText:
    print("B4 = %s" % tweet_abbrev['B4'])
    print(userText.replace('B4', tweet_abbrev['B4']).lower())
    
elif 'BFN' in userText:
    print("BFN = %s" % tweet_abbrev['BFN'])
    print(userText.replace('BFN', tweet_abbrev['BFN']).lower())
    
elif 'BR' in userText:
    print("BR = %s" % tweet_abbrev['BR'])
    print(userText.replace('BR', tweet_abbrev['BR']).lower())
    
elif 'BTW' in userText:
    print("BTW = %s" % tweet_abbrev['BTW'])
    print(userText.replace('BTW', tweet_abbrev['BTW']).lower())
    
elif 'CUL8R' in userText:
    print("CUL8R = %s" % tweet_abbrev['CUL8R'])
    print(userText('CUL8R', tweet_abbrev['CUL8R']).lower())
    
elif 'DAM' in userText:
    print("DAM = %s" % tweet_abbrev['DAM'])
    print(userText.replace('DAM', tweet_abbrev['DAM']).lower())
    
elif 'EMA' in userText:
    print("EMA = %s" % tweet_abbrev['EMA'])
    print(userText.replace('EMA', tweet_abbrev['EMA']).lower())
    
elif 'F2F' in userText:
    print("F2F = %s" % tweet_abbrev['F2F'])
    print(userText.replace('F2F', tweet_abbrev['F2F']).lower())
    
elif 'FTF' in userText:
    print("FTF = %s" % tweet_abbrev['FTF'])
    print(userText.replace('FTF', tweet_abbrev['FTF']).lower())
    
elif 'FB' in userText:
    print("FB = %s" % tweet_abbrev['FB'])
    print(userText.replace('FB', tweet_abbrev['FB']).lower())
    
elif 'HAGN' in userText:
    print("HAGN = %s" % tweet_abbrev['HAGN'])
    print(userText.replace('HAGN', tweet_abbrev['HAGN']).lower())
    
elif 'HAND' in userText:
    print("HAND = %s" % tweet_abbrev['HAND'])
    print(userText.replace('HAND', tweet_abbrev['HAND']).lower())
    
elif 'HOTD' in userText:
    print("HOTD = %s" % tweet_abbrev['HOTD'])
    print(userText.replace('HOTD', tweet_abbrev['HOTD']).lower())
    
elif 'HTH' in userText:
    print("HTH = %s" % tweet_abbrev['HTH'])
    print(userText.replace('HTH', tweet_abbrev['HTH']).lower())
    
elif 'IC' in userText:
    print("IC = %s" % tweet_abbrev['IC'])
    print(userText.replace('IC', tweet_abbrev['IC']).lower())
    
elif 'ICYMI' in userText:
    print("ICYMI = %s" % tweet_abbrev['ICYMI'])
    print(userText.replace('ICYMI', tweet_abbrev['ICYMI']).lower())
    
elif 'IDK' in userText:
    print("IDK = %s" % tweet_abbrev['IDK'])
    print(userText.replace('IDK', tweet_abbrev['IDK']).lower())
    
elif 'IIRC' in userText:
    print("IIRC = %s" % tweet_abbrev['IIRC'])
    print(userText.replace('IIRC', tweet_abbrev['IIRC']).lower())
    
elif 'IMHO' in userText:
    print("IMHO = %s" % tweet_abbrev['IMHO'])
    print(userText.replace('IMHO', tweet_abbrev['IMHO']).lower())
    
elif 'JK' in userText:
    print("JK = %s" % tweet_abbrev['JK'])
    print(userText.replace('JK', tweet_abbrev['JK']).lower())
    
elif 'JSYK' in userText:
    print("JSYK = %s" % tweet_abbrev['JSYK'])
    print(userText.replace('JSYK', tweet_abbrev['JSYK']).lower())
    
elif 'KK' in userText:
    print("KK = %s" % tweet_abbrev['KK'])
    print(userText.replace('KK', tweet_abbrev['KK']).lower())
    
elif 'LHH' in userText:
    print("LHH = %s" % tweet_abbrev['LHH'])
    print(userText.replace('LHH', tweet_abbrev['LHH']).lower())
    
elif 'LMK' in userText:
    print("LMK = %s" % tweet_abbrev['LMK'])
    print(userText.replace('LMK', tweet_abbrev['LMK']).lower())
    
elif 'LOL' in userText:
    print("LOL= %s" % tweet_abbrev['LOL'])
    print(userText.replace('LOL', tweet_abbrev['LOL']).lower())
    
elif 'NBD' in userText:
    print("NBD = %s" % tweet_abbrev['NBD'])
    print(userText.replace('NBD', tweet_abbrev['NBD']).lower())
    
elif 'NCT' in userText:
    print("NCT = %s" % tweet_abbrev['NCT'])
    print(userText.replace('NCT', tweet_abbrev['NCT']).lower())
    
elif 'NJOY' in userText:
    print("NJOY = %s" % tweet_abbrev['NJOY'])
    print(userText.replace('NJOY', tweet_abbrev['NJOY']).lower())
    
elif 'OMG' in userText:
    print("OMG = %s" % tweet_abbrev['OMG'])
    print(userText.replace('OMG', tweet_abbrev['OMG']).lower())
    
elif 'PLMK' in userText:
    print("PLMK = %s" % tweet_abbrev['PLMK'])
    print(userText.replace('PLMK', tweet_abbrev['PLMK']).lower())
    
elif 'SMH' in userText:
    print("SMH = %s" % tweet_abbrev['SMH'])
    print(userText.replace('SMH', tweet_abbrev['SMH']).lower())
    
elif 'SRS' in userText:
    print("SRS = %s" % tweet_abbrev['SRS'])
    print(userText.replace('SRS', tweet_abbrev['SRS']).lower())
    
elif 'TY' in userText:
    print("TY = %s" % tweet_abbrev['TY'])
    print(userText.replace('TY', tweet_abbrev['TY']).lower())
    
elif 'TYIA' in userText:
    print("TYIA = %s" % tweet_abbrev['TYIA'])
    print(userText.replace('TYIA', tweet_abbrev['TYIA']).lower())
    
elif 'TYVW' in userText:
    print("TYVM = %s" % tweet_abbrev['TYVM'])
    print(userText.replace('TYVW', tweet_abbrev['TYVW']).lower())
    
elif 'U' in userText:
    print("U = %s" % tweet_abbrev['U'])
    print(userText.replace('U', tweet_abbrev['U']).lower())
    
elif 'UR' in userText:
    print("UR = %s" % tweet_abbrev['UR'])
    print(userText.replace('UR', tweet_abbrev['UR']).lower())
    
elif 'WTV' in userText:
    print("WTV = %s" % tweet_abbrev['WTV'])
    print(userText.replace('WTV', tweet_abbrev['WTV']).lower())
    
elif 'YGTR' in userText:
    print("YGTR = %s" % tweet_abbrev['YGTR'])
    print(userText.replace('YGTR', tweet_abbrev['YGTR']).lower())
    
elif 'YOLO' in userText:
    print("YOLO = %s" % tweet_abbrev['YOLO'])
    print(userText.replace('YOLO', tweet_abbrev['YOLO']).lower())
    
elif 'YOYO' in userText:
    print("YOYO = %s" % tweet_abbrev['YOYO'])
    print(userText.replace('YOYO', tweet_abbrev['YOYO']).lower())
    
elif 'YW' in userText:
    print("YW = %s" % tweet_abbrev['YW'])
    print(userText.replace('YW', tweet_abbrev['YW']).lower())
    
elif 'ZOMG' in userText:
    print("ZOMG = %s" % tweet_abbrev['ZOMG'])
    print(userText.replace('ZOMG', tweet_abbrev['ZOMG']).lower()) 
else:
    print("Word?")
# Out:
# Please enter a tweet that is 160 characters or less: yoyo
# YOYO = You're on your own
# you're on your own
